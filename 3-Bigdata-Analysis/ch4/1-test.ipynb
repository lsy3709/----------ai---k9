# %%
import pickle
import re
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

docs = ["영화 정말 재미있다", "정말 지루한 영화", "배우 연기 최고"]
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(docs)        # 문서 × 단어 행렬
print(tfidf.get_feature_names_out()) # 단어 목록
print(X.toarray().round(2))          # TF-IDF 값
# Out:
# ['배우' '연기' '영화' '재미있다' '정말' '지루한' '최고']
# [[0.   0.   0.52 0.68 0.52 0.   0.  ]
#  [0.   0.   0.52 0.   0.52 0.68 0.  ]
#  [0.58 0.58 0.   0.   0.   0.   0.58]]

# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

okt = Okt()
def okt_tokenizer(text):
    return okt.morphs(text)          # 모든 형태소로 삐개기

# nsmc_train_df["document"]: 영화평 텍스트, ["label"]: 0/1
tfidf = TfidfVectorizer(tokenizer=okt_tokenizer, ngram_range=(1, 2), min_df=3)
X_train = tfidf.fit_transform(nsmc_train_df["document"])   # 시간 오래 걸림
model = LogisticRegression(C=3.5)
model.fit(X_train, nsmc_train_df["label"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       9 # nsmc_train_df["document"]: 영화평 텍스트, ["label"]: 0/1
#      10 tfidf = TfidfVectorizer(tokenizer=okt_tokenizer, ngram_range=(1, 2), min_df=3)
# ---> 11 X_train = tfidf.fit_transform(nsmc_train_df["document"])   # 시간 오래 걸림
#      12 model = LogisticRegression(C=3.5)
#      13 model.fit(X_train, nsmc_train_df["label"])
#
# NameError: name 'nsmc_train_df' is not defined
